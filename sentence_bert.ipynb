# %% [markdown]
# <a href="https://colab.research.google.com/github/LabMolUFG/SOFIA_integration/blob/main/sentence_bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly
# !pip install sentence-transformers

# %%
primary_odors = [
    "Drinking Water Primary odor", "Other Primary odor", "Waste Water Primary odor",
    "Urban Odor Primary odor", "Compost Primary odor", "Human Perception Primary odor",
    "Wine Primary odor", "Perfumes Primary odor", "Fragrance Primary odor",
    "City Smell Primary odor", "Chemical/ Hydrocarbon Primary odor", "Ammonia Primary odor",
    "Microbial Primary odor", "Cooked Primary odor", "Rotten Primary odor", "Ylang Primary odor",
    "Boiled Primary odor", "Grains Primary odor", "Cloth Primary odor", "Raw Primary odor",
    "Vegetation Primary odor", "Bland Primary odor", "Nose Feel Primary odor",
    "Fresh Primary odor", "Chocolate Primary odor", "Plants Primary odor",
    "Balsamic Primary odor", "Dry fruit Primary odor", "Burnt Primary odor",
    "Non-vegetarian Primary odor", "Dairy Primary odor", "Salty Primary odor",
    "Zesty Primary odor", "Metallic Primary odor", "Coal tar Primary odor",
    "Ripe/ Unripe Primary odor", "Waxy Primary odor", "Bloody Primary odor",
    "Fried Primary odor", "Clean Primary odor", "Poultry Primary odor",
    "Fecal/ Sewery Primary odor", "Bitter Primary odor", "Estery Primary odor",
    "Vegetables Primary odor", "Sulphur/ Cabbage/ Garlic Primary odor",
    "Chlorinous Primary odor", "Rancid/ Putrid Primary odor", "Medicinal/ Alcohol Primary odor",
    "Fragrant/ Fruity Primary odor", "Medicinal/ Phenolic Primary odor",
    "Terpenes/ Pine/ Lemon Primary odor", "Bakery Primary odor", "Rancid Primary odor",
    "Sweet Primary odor", "Restaurant Primary odor", "Fuel/ Gas Station/ Solvent Primary odor",
    "Grassy/ Woody Primary odor", "Putrid/ Dead Animal Primary odor",
    "Fishy/ Rancid Primary odor", "Fishy/ Ammonia Primary odor", "Woody/ Resinous Primary odor",
    "Sickening Primary odor", "Popcorn Primary odor", "Minty Primary odor",
    "Sharp/ Pungent Primary odor", "Non-citrus fruity Primary odor",
    "Chlorinous/ Ozonous Primary odor", "Lemon Primary odor", "Spices Primary odor",
    "Caramel Primary odor", "Nutty Primary odor", "Herbaceous Primary odor",
    "Floral Primary odor", "Woody Primary odor", "Pungent Primary odor",
    "Microbiological Primary odor", "Marshy/ Septic/ Sulphurous Primary odor",
    "Fruity Primary odor", "Earthy Primary odor", "Alliaceous Primary odor",
    "Hircine Primary odor", "Foul Primary odor", "Ambrosial Primary odor",
    "Nauseating Primary odor", "Aromatic Primary odor", "Soft oriental Primary odor",
    "Fragrant Primary odor", "Oriental Primary odor", "Green Primary odor",
    "Woody oriental Primary odor", "Water Primary odor", "Citrus Primary odor",
    "Soft floral Primary odor", "Mossy woods Primary odor", "Earthy/ Musty/ Moldy Primary odor",
    "Dry woods Primary odor", "Tobacco smoke Primary odor", "Beverage Primary odor",
    "People & animals Primary odor", "Nature Primary odor", "Food Primary odor",
    "Traffic emissions Primary odor", "Building materials & construction Primary odor",
    "Synthetic Primary odor", "Solvent/ Hydrocarbon Primary odor", "Non-food items Primary odor",
    "Industrial odours Primary odor", "Waste Primary odor", "Cleaning materials Primary odor",
    "Characteristic Primary odor", "Other Primary odor", "Baked Primary odor",
    "Dry Primary odor", "Smokey Primary odor", "Brown Primary odor"
]


sub_odors = [
    "Skunk Sub odor", "Gasoline Sub odor", "Earthy/ Potato Bin Sub odor", "Chemical Sub odor",
    "Sweet Solvent Sub odor", "Moth Balls Sub odor", "Glue Sub odor", "Ammonia Sub odor",
    "Irritating Sub odor", "Sharp Sub odor", "Metallic Sub odor", "Pungent Sub odor",
    "Fecal Sub odor", "Manure Sub odor", "Chloroform Sub odor", "Sewage Sub odor",
    "Rotten Vegetables Sub odor", "Burnt Rubber Sub odor", "Rotten Cabbage Sub odor",
    "Cabbage Sub odor", "Rotten Sub odor", "Natural Gas Sub odor", "Garlic Sub odor",
    "Corn Sub odor", "Decayed Sub odor", "Yeasty Sub odor", "Sour Milk Sub odor",
    "Fatty/ Oily Sub odor", "Sweaty Sub odor", "Pyridine Sub odor", "Sour Cheese Sub odor",
    "Putrid Sub odor", "Citrus Sub odor", "Soapy Sub odor", "Fruity Sub odor", "Green Sub odor",
    "Alkane Sub odor", "Pine Sub odor", "Borneol Sub odor", "Minty Sub odor", "Lemon Sub odor",
    "Terpenic Sub odor", "Eucalyptus Sub odor", "Carvone Sub odor", "Nail Polish Sub odor",
    "Linalool Sub odor", "Wet Wool Sub odor", "Sweet Garbage Sub odor", "Citral Sub odor",
    "Smokey Sub odor", "Biscuit Sub odor", "Roasted Sub odor", "Malty Sub odor", "Cookie Sub odor",
    "Toasty Sub odor", "Bready Sub odor", "Furfural Sub odor", "Rye bready Sub odor",
    "Marzipan Sub odor", "Graham cracker Sub odor", "Buttery Sub odor", "Vinegar Sub odor",
    "Sweet (Medicinal) Sub odor", "Bubblegum Sub odor", "Sugar Sub odor", "Vanilla Sub odor",
    "Marshmallow Sub odor", "Chocolate Sub odor", "Carbolic Sub odor", "Candy Sub odor",
    "Jammy Sub odor", "Fragrant Sub odor", "Warm Sub odor", "Cotton candy Sub odor",
    "Toffee Sub odor", "Benzene Sub odor", "Medicinal Sub odor", "Caramel Sub odor",
    "Beefy Sub odor", "Chicken Sub odor", "Coffee Sub odor", "Plastic Sub odor",
    "Fuel Sub odor", "Dead Animal Sub odor", "Alcohol Sub odor", "Urine Sub odor",
    "Burnt Wood Sub odor", "Mouldy Sub odor", "Vinyl Sub odor", "Spices Sub odor",
    "Cedarwood Sub odor", "Acid Sub odor", "Ethanol Sub odor", "Burnt Sub odor", "Foul Sub odor",
    "Peanut Butter Sub odor", "Almond Sub odor", "Solvent Sub odor", "Nutty Sub odor",
    "Resin Sub odor", "Oily Sub odor", "Fatty Sub odor", "Benzoin Sub odor", "Spearmint Sub odor",
    "Anisic Sub odor", "Menthol Sub odor", "Cool Sub odor", "Peppermint Sub odor",
    "Ketonic Sub odor", "Camphor Sub odor", "Acetoin Sub odor", "Sour Sub odor",
    "Tutty-Fruity Sub odor", "Strawberry Sub odor", "Banana Sub odor", "Pineapple Sub odor",
    "Cherry Sub odor", "Kerosene Sub odor", "Diesel Sub odor", "Cumin Sub odor",
    "Allspice Sub odor", "Pepper Sub odor", "Clove Sub odor", "Pesticide Sub odor",
    "Licorice Sub odor", "Cassia Sub odor", "Fennel Sub odor", "Caraway Sub odor",
    "Dill Sub odor", "Coriander Sub odor", "Nutmeg Sub odor", "Cinnamyl Sub odor",
    "Shoe Polish Sub odor", "Fenugreek Sub odor", "Cardamom Sub odor", "Eugenol Sub odor",
    "Black Pepper Sub odor", "Butterscotch Sub odor", "Molasses Sub odor", "Soy Sauce Sub odor",
    "Benzaldehyde Sub odor", "Honey Sub odor", "Raisin Sub odor", "Groundnut Sub odor",
    "Walnut Sub odor", "Peanut Sub odor", "Hazelnut Sub odor", "Hydrocarbon Sub odor",
    "Artichoke Sub odor", "Green Olive Sub odor", "Tobacco Sub odor", "Black Olive Sub odor",
    "Straw Sub odor", "Asparagus Sub odor", "Green Beans Sub odor", "Tarry Sub odor",
    "Tea Sub odor", "Bell Pepper Sub odor", "Freesia Sub odor", "Orange Blossom Sub odor",
    "Blooms Sub odor", "Lilac Sub odor", "Narcissus Sub odor", "Immortelle Sub odor",
    "Cleaning Fluid Sub odor", "Saffron Sub odor", "Cistus Sub odor", "Mahogany Sub odor",
    "Privet Sub odor", "Carnation Sub odor", "Linden flower Sub odor", "Fresh Cut Flower Sub odor",
    "Orchid Sub odor", "Bois de rose Sub odor", "Nitrile Sub odor", "Lily Sub odor",
    "Nasturtium Sub odor", "Jasmine Sub odor", "Tagette Sub odor", "Cyclamen Sub odor",
    "Muguet Sub odor", "Heliotrope Sub odor", "Chrysanthemum Sub odor", "Repellent Sub odor",
    "Magnolia Sub odor", "Gardenia Sub odor", "Peony Sub odor", "Camomile Sub odor",
    "Lily of the valley Sub odor", "Sawdust Sub odor", "Burnt Toast Sub odor",
    "Patchouli Sub odor", "Vetiver Sub odor", "Anaesthetic Sub odor", "Cedar Sub odor",
    "Sandalwood Sub odor", "Oak Sub odor", "Acetic Sub odor", "Fusel Sub odor",
    "Hot Sub odor", "Baker's Yeast Sub odor", "Ylang Sub odor", "Mousy Sub odor",
    "Horsey Sub odor", "Sauerkraut Sub odor", "Sweet Organic Chemical Sub odor",
    "Peach Sub odor", "Apple Sub odor", "Guava Sub odor", "Quince Sub odor", "Tropical Sub odor",
    "Blueberry Sub odor", "Papaya Sub odor", "Grape Sub odor", "Chlorinous Sub odor",
    "Prune Sub odor", "Blackberry Sub odor", "Mango Sub odor", "Durain Sub odor",
    "Plum Sub odor", "Ripe Sub odor", "Mercaptan Sub odor", "Pear Sub odor", "Apricot Sub odor",
    "Juicy Sub odor", "Unripe fruit Sub odor", "Cantaloupe Sub odor", "Passion fruit Sub odor",
    "Grapefruit Sub odor", "Pulpy fruit Sub odor", "Tangerine Sub odor", "Pyrazine Sub odor",
    "Blackcurrant Sub odor", "Melon Sub odor", "Fig Sub odor", "Pomegranate Sub odor",
    "Rotting fruit Sub odor", "Berry Sub odor", "Lychee Sub odor", "Dried Fruit Sub odor",
    "Artificial Fruit Sub odor", "Aldehydic Sub odor", "Kiwi Sub odor", "Raspberry Sub odor",
    "Dusty Sub odor", "Mushroom Sub odor", "Alliaceous Sub odor", "Goat Sub odor",
    "Wet Dog Sub odor", "Offensive Sub odor", "Acrid Sub odor", "Suffocating Sub odor",
    "Harsh Sub odor", "Stench Sub odor", "Fermented Sub odor", "Decomposing Sub odor",
    "Choking Sub odor", "Ether Sub odor", "Unpleasant Sub odor", "Obnoxious Sub odor",
    "Stinky Sub odor", "Garbage Sub odor", "Sickening Sub odor", "Disagreeable Sub odor",
    "Repulsive Sub odor", "Dead Sub odor", "Musk Sub odor", "Disgusting Sub odor",
    "Sulphurous Sub odor", "Lavender Sub odor", "Amber Sub odor", "Incense Sub odor",
    "Oriental Sub odor", "Carbide Sub odor", "Violet Leaves Sub odor", "Galbanum Sub odor",
    "Aquatic Sub odor", "Water Sub odor", "Marine Sub odor", "Wet Air Sub odor",
    "Thiamine Sub odor", "Lactonic Sub odor", "Bergamot Sub odor", "Mandarin Sub odor",
    "Powdery Sub odor", "Oak Moss Sub odor", "Acetone Sub odor", "Cigar Sub odor",
    "Cigarette Sub odor", "Marijuana Sub odor", "Scotch Sub odor", "Varnish Sub odor",
    "Absinthe Sub odor", "Root beer Sub odor", "Beer Sub odor", "Fusel Oil Sub odor",
    "Burnt Paper Sub odor", "Heavy Sub odor", "Marijuana Type Sub odor", "Animal Sub odor",
    "Body Odor Sub odor", "Dirty Socks Sub odor", "Sweat Sub odor", "Musty Sub odor",
    "Muddy Sub odor", "Pencil Sub odor", "Strong Sub odor", "Pine Oil Sub odor",
    "Disinfectant Sub odor", "Rubber Sub odor", "Matches Sub odor", "Sulfur Sub odor"
]

objects = [
    "ceiling", "wall", "court", "net", "person", "racquet", "light troffer", "grille", "head",
    "right arm", "left arm", "back", "left leg", "left foot", "right leg", "right foot",
    "exercise machine", "mirror", "floor", "bench", "ceiling recessed light", "window",
    "flush mount light", "chair", "basket", "treadmill", "rowing machine", "speaker",
    "cabinet", "music system", "grass", "path", "sand", "climbing frame", "house", "fence",
    "trees", "sky", "cloud", "tree", "door", "roof", "playground", "bucket", "boat", "ground",
    "water", "building", "hills", "road", "bicycle", "buildings", "post", "ice rink", "goal",
    "mezzanine", "ice hockey rink", "ceiling spotlight", "grandstand", "field", "gate",
    "handrail", "railing", "staircase", "track", "ball", "bat", "pendant lamp", "rug",
    "right hand", "left hand", "gaze", "box", "toy", "cap", "club", "light post", "mountain",
    "embankment", "sign", "plants", "stones", "stick", "torso", "eye", "mouth", "rifle",
    "steps", "column", "clothes rack", "stool", "flowerpot", "plant", "towels", "hot tub",
    "curtain", "step", "flowers", "pool", "umbrella", "bar", "people", "chandelier",
    "motorbike", "notice board", "vending machine", "arcade machine", "bandstand", "car",
    "gazebo", "footpath", "statue", "canopy", "shutter", "table", "double door", "ski slope",
    "van", "windshield", "bathtub", "flag", "fluorescent tube", "sword", "fan", "mat",
    "wardrobe", "text", "sea water", "pitch", "carousel", "stand", "sidewalk", "model",
    "bulletin board", "bulb", "trash can", "traffic light", "parking meter", "fire hydrant",
    "street light", "pane", "terraces", "bullring", "capital", "base", "shaft", "counter",
    "target", "fountain", "spotlight", "arcades", "balustrade", "seat", "neck",
    "volleyball court", "ring", "ladder", "platform", "swimming pool ladder", "clock",
    "swimming pool", "big top", "pole", "sand trap", "rake", "tower", "rocket",
    "roller coaster", "fairground ride", "palm tree", "satellite dish", "awning", "brand name",
    "tank", "structure", "funfair", "organ", "seats", "stage", "grand piano", "boxes", "cars",
    "deck chair", "trellis", "trunk", "ceiling fan", "sink", "bed", "towel", "faucet",
    "bowl", "side table", "cooker", "flower", "tray", "pitcher", "candle", "vase", "blade",
    "blind", "golf cart", "mountains", "rocks", "caravan", "nose", "benches", "traffic cone",
    "branch", "sculpture", "lake", "island", "monument", "chain", "book", "basketball hoop",
    "scoreboard", "table football", "table tennis", "billiard table", "blackboard", "board",
    "picture", "balls", "corner pocket", "side pocket", "ball storage", "rail", "heater",
    "pool ball", "table lamp", "leg", "animal", "sauna", "ladle", "thermometer", "windows",
    "machine", "purse", "bleachers", "fish", "backpack", "bottle", "locker", "lockers",
    "clothes", "labyrinth", "beam", "punching bag", "belt", "dumbbells", "extractor fan",
    "pipe", "motor", "skylight", "bulbs", "sconce", "outlet", "camera", "advertisement",
    "wheel", "rim", "headlight", "license plate", "hill", "roulette", "chips", "armchair",
    "billboard", "arm", "arm support", "games table", "monitor", "slot machines",
    "slot machine", "screen", "sofa", "coffee table", "cushion", "pillow", "sand beach",
    "forecourt", "bonfire", "top", "rock", "artificial golf green", "hole", "golf club",
    "racket", "columns", "bowling alley", "tunnel", "air conditioning", "bowling pins",
    "spotlights", "drum", "golf bag", "tent", "inflatable bounce game", "inflatable glove",
    "games", "snow", "taillight", "elevator door", "shelves", "steering wheel", "dashboard",
    "safety belt", "wall recessed light", "divider", "light switch", "handle", "door frame",
    "jacket", "gear shift", "dock", "boats", "bag", "conveyor belt", "suitcase", "trolley",
    "ear", "hair", "knob", "swivel chair", "instrument panel", "range", "kettle", "work surface",
    "paper towels", "oven", "stove", "burner", "button panel", "microwave", "refrigerator",
    "drawer", "luggage rack", "newspaper", "truck", "pot", "shelf", "map", "glass", "plate",
    "napkin", "fork", "seat cushion", "fruits", "mug", "sash", "muntin", "stile",
    "back pillow", "exhibitor", "service elevator", "escalator", "balcony", "baggage carts",
    "wall spotlight", "air vent", "shops", "shop", "check-in-desk", "barrier", "chairs",
    "revolving door", "ticket counter", "controls", "control panel", "cockpit", "meters",
    "meter", "armrest", "stone", "land", "cliff", "river water", "branches", "bus",
    "wheelbarrow", "floe", "rope", "topiary tree", "mill", "cave", "palm trees", "crevasse",
    "dirt track", "canyon", "weeds", "bridge", "waterfall", "plant pots", "wood", "ship",
    "clouds", "trench", "horse", "stream", "footbridge", "hay roll", "viewpoint", "chimney",
    "forest", "curb", "manhole", "shoe", "sun", "bird", "sand dune", "canoe", "dam",
    "rocky formation", "valley", "mountain pass", "iceberg", "ice", "skeleton", "baby carriage",
    "baptismal font", "altar", "altarpiece", "candelabra", "podium", "jar", "can", "cans",
    "bags", "switch", "papers", "diffusor", "shade", "projection screen", "television",
    "desk", "diploma", "canister", "books", "remote control", "bookcase", "poster", "paper",
    "drawing", "printer", "face", "hand", "aperture", "projector", "folder", "desks",
    "toys", "cloth", "easel", "canvas", "palette", "desk lamp", "brush", "upper sash",
    "lower sash", "casing interior", "radiator", "chest of drawers", "floor lamp", "roll",
    "cat", "interior casing", "necklace", "spindle", "h-stretcher", "brochures", "frame",
    "pen", "ticket booth", "aquarium", "notebook", "music stand", "throne", "sprinkler",
    "ottoman", "cabinets", "catwalk", "cup", "airplane", "showcase", "microphone", "skirt",
    "fire extinguisher", "butane gas cylinder", "door bars", "bars", "niche", "cannon",
    "piano", "pulpit", "witness stand", "vault", "cross", "shrine", "confessional booth",
    "television camera", "tripod", "cells", "semi-flush mount light", "guitar", "carpet",
    "coffin", "torchiere lamp", "computer case", "chair desk", "file cabinet", "envelopes",
    "file", "notebooks", "tie", "buttons", "button", "lock", "gear", "dome", "dress",
    "apron", "stretcher", "dvds", "calendar", "headboard", "night table", "trousers",
    "sneaker", "laptop", "folders", "bedpost", "light source", "highlight", "dresser",
    "telephone", "post-it", "mouse", "fireplace", "hinge", "front", "panel", "ashtray",
    "bottle rack", "magazine", "seat base", "blanket", "cradle", "mobile", "footboard",
    "safety side", "rack", "side", "utensils canister", "toaster", "ice maker", "dishwasher",
    "coffee maker", "display", "frying pan", "saucepan", "tube", "console table", "dial",
    "food", "extractor hood", "vent", "body", "teapot", "dishcloth", "dish rack",
    "baseboard", "foot", "filter", "mitten", "washing machine", "soap dispenser",
    "detergent dispenser", "cord", "skimmer", "cheese dish", "casserole", "knife set",
    "candle holder", "figurine", "shell", "blender", "kitchen island", "bottles", "scales",
    "tumble dryer", "towel paper", "plates", "tin", "cutlery", "closet", "scourer",
    "plate rack", "sash lock", "sill", "bread box", "hotplate", "food processor",
    "place mat", "spout", "pepper shaker", "spoon", "bread", "knife", "soap bottle",
    "sponge", "griddle", "rocking chair", "decoration", "wire", "cutting board", "napkin holder",
    "spice rack", "salt", "dog dish", "coaster", "bread lift", "foot rest", "countertop",
    "pepper", "sockets", "background", "screw", "bowls", "tureen", "lid", "fruit",
    "radio", "spice jar", "dollhouse", "rocking horse", "towel rack", "shower stall",
    "curtain rod", "toilet", "cistern", "tank lid", "shower screen", "toilet paper",
    "flusher", "tap", "towel ring", "plug", "overflot plate", "drain", "pedestal",
    "towel rail", "soap", "shower", "soap dish", "hair dryer", "tissue box", "hanger",
    "towel dispenser", "toilet brush", "bidet", "toilet paper holder", "casing",
    "hook", "ice bucket", "soaps", "backplate", "shaving brush", "shower faucet",
    "tapestry", "dumbbell", "sheet", "leaf", "shoes", "umbrella stand", "chest",
    "side rail", "boot", "tallboy", "duvet", "sideboard", "violin", "score", "keys",
    "hat", "watering can", "water cooler", "bell", "table runner", "inside arm",
    "outside arm", "runner", "opening", "stem", "label", "folding screen", "earmuffs",
    "fireplace utensils", "grinder", "pottery", "teacup", "sugar bowl", "runner cloth",
    "shower room", "iron", "shawl", "sports bag", "sweater", "sweaters", "hangers",
    "shirt", "boots", "sneakers", "t-shirt", "shirts", "t-shirts", "desk organizer",
    "magazines", "keyboard", "receiver", "transformer", "computer", "mousepad",
    "typewriter", "adding machine", "cage", "file box", "calculator", "laptop bag",
    "cell phone", "mattress", "arm panel", "vcr", "doors", "fringe", "stringer",
    "newspapers", "table cloth", "chess", "magazine rack", "cover curtain", "sea star",
    "television stand", "centerpiece", "dvd", "wine rack", "suit hanger", "tissue",
    "glasses", "coat rack", "support", "padlock", "manchette", "rocker", "pack",
    "potatoes", "onions", "pantry", "baskets", "tins", "alarm clock", "skirting board",
    "latch", "dvd player", "brochure", "head rail", "slats", "grating", "paper weight",
    "mask", "sleeping robe", "eyeglasses", "cover", "night light", "bedspring", "dog",
    "sofa bed", "aerial", "sewing machine", "metal shutter", "funnel", "portable fridge",
    "buckets", "tricycle", "broom", "tools", "spanners", "hammer", "tools box",
    "table game", "tennis table", "legs", "fish tank", "cue", "pool balls", "cue rack",
    "chalk", "safety rail", "dormer", "pond", "shelter", "ski lift", "plank", "jack",
    "tomb", "barbecue", "tread", "riser", "cake", "breads", "tongs", "rotisserie",
    "grill", "straw", "forklift", "hut", "cart", "shore", "container", "tractor",
    "housing", "recycling bin", "banner", "bumper", "tree trunk", "central reservation",
    "street box", "mast", "smoke detector", "motorboat", "crane", "railway", "scarf",
    "shipyard", "aircraft carrier", "chaise lounge", "star", "helmet", "runway",
    "book stand", "fluorescent tubes", "pergola", "bicycle rack", "bus stop",
    "telephone booth", "ironing board", "glacier", "truck crane", "synthesizer",
    "sweatshirts", "sweatshirt", "algae", "utensils", "scratching post", "trays",
    "garage", "wheels", "pier", "bicycles", "clothes hanging", "scarfs", "building materials",
    "balloon", "eaves", "sticks", "gutter", "crosswalk", "service station", "hollow",
    "wing", "turbine engine", "ruins", "well", "menu", "mailbox", "knocker", "helicopter",
    "fuselage", "entrance", "toll plaza", "hen", "hood", "stabilizer", "landing gear",
    "temple", "viaduct", "flag pole", "lighthouse", "fire escape", "ticket office",
    "log", "shop window", "rakes", "leave", "train", "stall", "price tag", "control tower",
    "trailer", "greenhouse", "plastic", "duck", "carriage", "ferris wheel", "shanty",
    "shanties", "landfill", "hanging clothes", "carport", "roof rack", "gas cap",
    "ramp", "shovel", "bone", "propeller", "entry phone", "headstones", "headstone",
    "hammock", "arch", "finger", "kiosk", "wheelchair", "garland", "puddle", "trash bag",
    "newspaper stand", "trash bags", "plaque", "dummy", "tramway", "skip",
    "sidewalk cafe", "alarm", "street number", "house number", "hip tiles", "scaffolding",
    "stadium", "trestle", "stairs", "porch", "junk", "arcade", "wiper", "tables",
    "terrace", "fire alarm", "sunglasses", "tarp", "trash", "parterre", "block", "post box",
    "tombstones", "kennel", "lamp housing", "garage door", "skyscraper", "amphitheater",
    "rubble", "floor spotlight", "obelisk", "steel industry", "vane", "covered bridge",
    "aqueduct", "windmill", "tracks", "watchtower", "barbed wire", "shopping carts",
    "weighbridge", "petrol pump", "fender", "vineyard", "sewer", "cabin", "henhouse",
    "leaves", "roundabout", "water mill", "water wheel", "patio", "elevator", "workbench",
    "wall spotlights", "trough", "coop", "piston", "display board", "lectern", "napkins",
    "notepad", "security camera", "cubicle", "telescope", "pigeonhole", "reel", "lab bench",
    "cages", "grille door", "clipboard", "photocopier", "engine", "pipes", "articulated lamp",
    "equipment", "slotted spoon", "hair spray", "spray", "hairbrush", "dental chair",
    "cards", "merchandise", "pallets", "pallet", "barrel", "alembic", "terminal",
    "leash", "stethoscope", "paper filer", "mechanical shovel", "boiler", "valve", "beds",
    "tanks", "washing machines", "dartboard", "control table", "water dispenser",
    "cpu", "cds", "cd", "stapler", "tape", "desk mat", "hard drive", "test tube", "office",
    "logo", "candy", "pumpkin", "cash register", "packs", "briefcase", "coat", "videos",
    "video", "stalls", "urinal", "cakes", "bread rolls", "heel shoe", "monitors",
    "flip flop", "wallet", "stands", "fruit stand", "first floor", "hairdresser chair",
    "shaker", "watch", "cups", "gravy boat", "barrels", "blast furnace", "bulldozer",
    "water tower", "smoke", "steam shovel", "brick", "recycling materials", "cave entrance",
    "root", "cardboard", "excavator", "weights", "stationary bicycle", "barbell",
    "gym machine", "weight", "exercise bikes", "exercise machines", "exercise bench",
    "horizontal bar", "asymmetric bars", "treadmills", "building arena", "steamroller",
    "gates", "velodrome", "camcorder", "putting green", "game", "swings", "slide",
    "sandbox", "swing", "slides", "playground equipment", "overhang", "seesaw", "hose",
    "poles", "bear cutout", "tires", "houses", "material", "gravel", "bushes", "tire seat",
    "childish games", "park gear", "bounce seat", "seating", "fish structure", "bush",
    "hedge", "signs", "sandpit", "flowerpots", "spade", "globe", "golf sticks", "gun",
    "trunks", "pillar", "cases", "paper cup", "right shoulder", "left shoulder", "mosaic",
    "petal", "swmming pool", "float", "planter", "bathrobe", "tennis court",
    "basketball court", "pylon", "sand track", "lawn mower", "plant pot", "video camera",
    "fern", "balloons", "baloons", "pelota court", "crank", "snow track", "doort", "ski",
    "ski trail", "glove", "skis", "sled", "slope", "sky lift", "chairs lift", "cable",
    "chair lift", "lift", "floodlights", "playing field", "teeth", "eyebrow", "pavilion",
    "coastline", "quay", "seal", "equestrian obstacle", "starting gate", "rider", "number",
    "starting gate trolley", "ice track", "tablet", "hockey rink", "puff doll", "pad",
    "whip", "stagelight", "railings", "floodlight", "supporting iron metal", "circus",
    "hobby-horse", "shield", "hobby-elephant", "models", "lights", "light bulb", "soccer goal",
    "steam roller", "bull", "cape", "cloak", "bullfighter", "horn", "cabins", "earphones",
    "instrument", "shooting pad", "supporting metal", "litter basket", "creeper", "backpacks",
    "football table", "arcade machines", "pinball", "change machine", "village", "tarpaulin",
    "diving board", "rubber ring", "girder", "cane", "canes", "handr", "desk chair",
    "cubicles", "covered wagon", "paving stone", "dice", "chip", "reaper", "ride",
    "wires", "tinsel", "christmas lights", "fence rubble", "castle", "booth", "merry-go-round",
    "boardwalk", "fairground attraction", "booths", "sea", "seagull", "big wheel", "tents",
    "trailers", "roller coaster cars", "cable car", "walkway", "hillside", "tarmac", "fog",
    "hay stacks", "pumpkins", "squash", "fairground", "pavilions", "horse carousel",
    "ride structure", "park", "beams", "cranes", "ticket box", "ceiling spotlights",
    "baseball field", "gloves", "baseball glove", "clubs", "plant tree", "tyrees", "trtees",
    "buildigs", "sailboat", "trampoline", "drinking fountain", "massage bed", "golf ball",
    "golg club", "golfer", "marker", "shrubs", "stone slab", "banker", "skating rink",
    "schoolyard", "cub", "window rose", "bollard", "shopping cart", "ducks", "moon",
    "pond water", "fags", "flags", "squirrel", "picnic spot", "cool box", "cement",
    "pool bar", "cues", "tiger", "elephant", "steam room", "thermostat", "water chute",
    "skate", "obstacle", "indoor track", "killer whale", "dolphin", "deck", "drums",
    "cymbal", "showers", "poncho", "padlocks", "steel", "ropes", "boxing gloves",
    "white mark", "loudspeaker", "wall re", "racetrack", "racing track", "speedway",
    "mobile home", "race car", "race circuit", "fences", "deck boat", "sail", "ornament",
    "craps table", "card table", "peak", "shoulder", "ornamental structure", "plinth",
    "roulette table", "card", "fruit machine", "game table", "games room", "floor light",
    "light display", "video game", "basketball", "maze", "muffin", "deck chairs", "umbrellas",
    "menus", "hay bale", "disk", "lemon", "golf green", "strips", "monkey", "hippopotamus head",
    "bottom rail", "cube", "inflatable park", "inflatable toy", "graund", "kite string",
    "wsall", "skittle", "skittles", "skittle alley", "skittle alleys", "bowling alleys",
    "bowling ball return", "ball rack", "ball stands", "banners", "medal", "running track",
    "hurdle", "postes", "flask", "truk", "cooler", "light tower", "elevator doors",
    "glove compartment", "gas pedal", "brake pedal", "clutch pedal", "odometer", "gearshift",
    "head sport", "seat belt clipper", "seat belt", "rear dash", "papr", "wood board",
    "boards", "filing cabinet", "berth", "blankets", "record player", "headrest",
    "lower deck", "menu card", "pendant", "plastic cup", "buses", "trolleys", "baby chair",
    "folding door", "painting", "swimsuit", "slipper", "vacuum cleaner", "security cordon",
    "rudder", "recessed light", "wheelhouse", "console", "hatch", "railroad", "rails",
    "train tracks", "subway", "railroad track", "sport bag", "package", "floor recessed light",
    "ceiling lamp", "separation", "light switches", "sliding door", "wood stove",
    "corkscrew", "dishrack", "squeezer", "coffee cup", "strainer", "saucepans", "spatula",
    "switches", "pressure cooker", "gripper", "luggage", "footrest", "bouquet", "veil",
    "railroad train", "platf", "post light", "photo machine", "ticket machine", "support pole",
    "oar", "checkpoint", "security checkpoint", "scanner", "seat water", "hoist", "counters",
    "glass wall", "suitcases", "digital clock", "buttress", "carts", "check-in-desks", "tile",
    "screens", "store", "landing track", "pendant lamps", "moving walkway", "pala",
    "airlock", "lever", "joystick", "gears", "headphones", "steering", "harness",
    "flight deck", "camouflage", "control panels", "suit", "ceiling controls", "airplanes",
    "hardware", "button box", "key pad", "level", "window frame", "cables", "switchboard",
    "power outlet", "radar screen", "sand hill", "cliffs", "badlands", "mound",
    "parking lot", "barren land", "badlands hills", "basin", "woman", "canyons", "shrub",
    "apple", "lava", "river", "sheep", "semidesert ground", "salt plain", "desert field",
    "cow", "sand dunes", "rubber boat", "diving goggles", "fire", "crater", "mustache",
    "shorts", "plateau", "tree trunks", "scrubland", "tree top", "tree leaves", "undergrowth",
    "trees top", "ground leaves", "snowy", "walrus", "ice ground", "persons", "sean lion",
    "sea lion", "drift ice", "ice field", "rope bridge", "suspension bridge", "sun deck",
    "skywalk", "telegraph pole", "suspension rope bridge", "topiary trees", "steet light",
    "animal topiary", "ree", "tableland", "urban valley", "clabe car", "whitewater", "wave",
    "surfboard", "buoys", "surf", "rowing", "combine harvester", "wheat", "wheat spike",
    "boillers", "furrow", "savanna", "scrubs", "zebra", "cavern", "rocky wall", "rocky ground",
    "starfish", "ray", "sinkhole", "desert ground", "desert", "cactus", "ground shrubs",
    "ice wall", "ice mountain", "stalactite", "vegetables", "grass field", "sunflowers field",
    "vine", "straw bale", "pplant", "rocky mountains", "paddle", "bamboo cane", "bamboo canes",
    "rock formation", "islet", "trucks", "beach lake", "foliage", "lake house", "rainbow",
    "raft", "urbanization", "moss", "ground desert", "doll", "sandals", "tortoise",
    "person sitting", "cloudy sky", "water surf", "animals", "tail", "water bog", "bog water",
    "hen house", "stump", "planat", "bakk", "riad", "parking place", "tinb", "flock of sheep",
    "barn", "foal", "sheep pen", "chicken", "milestone", "sly", "rod", "swan", "roks",
    "airpl", "ballon", "hot air balloon", "rafting", "jground", "pebbles", "white water",
    "soil", "stone path", "platns", "breakwater", "gull", "snowy ground", "snow covered ground",
    "remote control car", "snow covered plain", "seaplane", "hay rolls", "fog bank",
    "snowy road", "snowy mountain pass", "rocky plain", "rocky mountain", "refuge",
    "snowy trees", "snowy", "snowy", "snowy"
]

# %%
classes_1 = sub_odors # Caminho do primeiro arquivo
classes_2 = objects  # Caminho do segundo arquivo


from sentence_transformers import SentenceTransformer, util
import numpy as np

# 1. Carregar o modelo SBERT
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# 2. Codificar as duas listas de classes usando SBERT
embeddings_1 = model.encode(classes_1, convert_to_tensor=True)
embeddings_2 = model.encode(classes_2, convert_to_tensor=True)

# 3. Calcular a similaridade entre as classes das duas listas usando similaridade do cosseno
cos_similarities = util.cos_sim(embeddings_1, embeddings_2)

# 4. Exibir a matriz de similaridade normalizada com os nomes dos odores e objetos
print("Similaridade entre odores e objetos (normalizada):")
for i, odor in enumerate(classes_1):
    for j, obj in enumerate(classes_2):
        similarity = cos_similarities[i][j].item()  # Acessa o valor da similaridade
        print(f"Odor: {odor} - Objeto: {obj} | Similaridade: {similarity:.3f}")

# 5. Para salvar a matriz de similaridade em arquivo com os pares e suas similaridades (opcional)
with open('similaridades_sub_odors.csv', 'w') as f:
    f.write("Odor,Objeto,Similaridade\n")
    for i, odor in enumerate(classes_1):
        for j, obj in enumerate(classes_2):
            similarity = cos_similarities[i][j].item()
            f.write(f"{odor},{obj},{similarity:.3f}\n")
